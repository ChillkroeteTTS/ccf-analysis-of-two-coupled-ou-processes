# %%
import pandas as pd
df1 = pd.DataFrame({'ou1': [1, 2, 1, 1, 2], 'ou2': [3, 4, 5, 6, 3]})
df2 = pd.DataFrame({'ou1': [1, 2, 1, 1, 2], 'ou2': [3, 4, 5, 6, 3]}) + 1
merged = df1.merge(df2, left_index=True, right_index=True)

# %%
from stats import group_by_index
group_by_index([df1, df2]).median()
# Out:
#    ou1  ou2
# 0  1.5  3.5
# 1  2.5  4.5
# 2  1.5  5.5
# 3  1.5  6.5
# 4  2.5  3.5

# %%
df1.index.name

# %%
from file_handling import  load_ensemble 
from pathlib import Path
load_ensemble(Path('../results/30_100_0'))[0]['ensemble'].filter(like='ou').plot()
# Out:
# <AxesSubplot:>
